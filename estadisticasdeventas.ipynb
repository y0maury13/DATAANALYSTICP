# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df_estadisticas =pd.read_csv("dato.csv")

# %%
df_estadisticas
# Out:
#      Platform     Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 0         Wii    Sports              Nintendo    41,36    28,96     3,77
# 1         Wii    Racing              Nintendo    15,68     12,8     3,79
# 2         Wii    Sports              Nintendo    15,61    10,95     3,28
# 3          DS  Platform              Nintendo    11,28     9,15      6,5
# 4         Wii      Misc              Nintendo    13,96     9,18     2,93
# ...       ...       ...                   ...      ...      ...      ...
# 7107       PC    Action               Ubisoft        0        0        0
# 7108       PC   Shooter          Midway Games        0        0        0
# 7109       PC    Sports                  Sega        0        0        0
# 7110       PC  Strategy  Take-Two Interactive        0        0        0
# 7111      PS4  Platform             Team Meat        0        0        0
#
#      Other_Sales Global_Sales Rating Critic_Score_Class
# ...

# %%
df_estadisticas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Platform            7112 non-null   object
#  1   Genre               7112 non-null   object
#  2   Publisher           7112 non-null   object
#  3   NA_Sales            7112 non-null   object
#  4   EU_Sales            7112 non-null   object
#  5   JP_Sales            7112 non-null   object
#  6   Other_Sales         7112 non-null   object
#  7   Global_Sales        7112 non-null   object
#  8   Rating              7112 non-null   object
#  9   Critic_Score_Class  7112 non-null   object
# dtypes: object(10)
# memory usage: 555.8+ KB

# %%
df_estadisticas.head
# Out:
# <bound method NDFrame.head of      Platform     Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 0         Wii    Sports              Nintendo    41,36    28,96     3,77
# 1         Wii    Racing              Nintendo    15,68     12,8     3,79
# 2         Wii    Sports              Nintendo    15,61    10,95     3,28
# 3          DS  Platform              Nintendo    11,28     9,15      6,5
# 4         Wii      Misc              Nintendo    13,96     9,18     2,93
# ...       ...       ...                   ...      ...      ...      ...
# 7107       PC    Action               Ubisoft        0        0        0
# 7108       PC   Shooter          Midway Games        0        0        0
# 7109       PC    Sports                  Sega        0        0        0
# 7110       PC  Strategy  Take-Two Interactive        0        0        0
# 7111      PS4  Platform             Team Meat        0        0        0
#
#      Other_Sales Global_Sales Rating Critic_Score_Class
# ...

# %%
print(df_estadisticas["Platform"])
# Out:
# 0       Wii
# 1       Wii
# 2       Wii
# 3        DS
# 4       Wii
#        ...
# 7107     PC
# 7108     PC
# 7109     PC
# 7110     PC
# 7111    PS4
# Name: Platform, Length: 7112, dtype: object

# %%
print(df_estadisticas["Publisher"])
# Out:
# 0                   Nintendo
# 1                   Nintendo
# 2                   Nintendo
# 3                   Nintendo
# 4                   Nintendo
#                 ...
# 7107                 Ubisoft
# 7108            Midway Games
# 7109                    Sega
# 7110    Take-Two Interactive
# 7111               Team Meat
# Name: Publisher, Length: 7112, dtype: object

# %%
print(df_estadisticas["Publisher"],df_estadisticas["Platform"])
# Out:
# 0                   Nintendo
# 1                   Nintendo
# 2                   Nintendo
# 3                   Nintendo
# 4                   Nintendo
#                 ...
# 7107                 Ubisoft
# 7108            Midway Games
# 7109                    Sega
# 7110    Take-Two Interactive
# 7111               Team Meat
# Name: Publisher, Length: 7112, dtype: object 0       Wii
# 1       Wii
# 2       Wii
# 3        DS
# 4       Wii
#        ...
# 7107     PC
# 7108     PC
# 7109     PC
# 7110     PC
# 7111    PS4
# Name: Platform, Length: 7112, dtype: object

# %%
df_estadisticas.describe()
# Out:
#        Platform   Genre        Publisher NA_Sales EU_Sales JP_Sales  \
# count      7112    7112             7112     7112     7112     7112
# unique       17      12              278      349      272      160
# top         PS2  Action  Electronic Arts        0        0        0
# freq       1169    1698              971      642     1015     5052
#
#        Other_Sales Global_Sales Rating Critic_Score_Class
# count         7112         7112   7112               7112
# unique         147          542      7                  4
# top           0,01         0,02      T          Excelente
# freq          1575          221   2489               1997

# %%
df_estadisticas.head()
# Out:
#   Platform     Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0      Wii    Sports  Nintendo    41,36    28,96     3,77        8,45
# 1      Wii    Racing  Nintendo    15,68     12,8     3,79        3,29
# 2      Wii    Sports  Nintendo    15,61    10,95     3,28        2,95
# 3       DS  Platform  Nintendo    11,28     9,15      6,5        2,88
# 4      Wii      Misc  Nintendo    13,96     9,18     2,93        2,84
#
#   Global_Sales Rating Critic_Score_Class
# 0        82,54      E              Bueno
# 1        35,57      E          Excelente
# 2        32,78      E          Excelente
# 3        29,81      E          Excelente
# 4        28,92      E               Malo

# %%
df_estadisticas.info(["Publisher"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Platform            7112 non-null   object
#  1   Genre               7112 non-null   object
#  2   Publisher           7112 non-null   object
#  3   NA_Sales            7112 non-null   object
#  4   EU_Sales            7112 non-null   object
#  5   JP_Sales            7112 non-null   object
#  6   Other_Sales         7112 non-null   object
#  7   Global_Sales        7112 non-null   object
#  8   Rating              7112 non-null   object
#  9   Critic_Score_Class  7112 non-null   object
# dtypes: object(10)
# memory usage: 555.8+ KB

# %%
print(df_estadisticas)
# Out:
#      Platform     Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 0         Wii    Sports              Nintendo    41,36    28,96     3,77
# 1         Wii    Racing              Nintendo    15,68     12,8     3,79
# 2         Wii    Sports              Nintendo    15,61    10,95     3,28
# 3          DS  Platform              Nintendo    11,28     9,15      6,5
# 4         Wii      Misc              Nintendo    13,96     9,18     2,93
# ...       ...       ...                   ...      ...      ...      ...
# 7107       PC    Action               Ubisoft        0        0        0
# 7108       PC   Shooter          Midway Games        0        0        0
# 7109       PC    Sports                  Sega        0        0        0
# 7110       PC  Strategy  Take-Two Interactive        0        0        0
# 7111      PS4  Platform             Team Meat        0        0        0
#
#      Other_Sales Global_Sales Rating Critic_Score_Class
# ...

# %%
(df_estadisticas)
# Out:
#      Platform     Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 0         Wii    Sports              Nintendo    41,36    28,96     3,77
# 1         Wii    Racing              Nintendo    15,68     12,8     3,79
# 2         Wii    Sports              Nintendo    15,61    10,95     3,28
# 3          DS  Platform              Nintendo    11,28     9,15      6,5
# 4         Wii      Misc              Nintendo    13,96     9,18     2,93
# ...       ...       ...                   ...      ...      ...      ...
# 7107       PC    Action               Ubisoft        0        0        0
# 7108       PC   Shooter          Midway Games        0        0        0
# 7109       PC    Sports                  Sega        0        0        0
# 7110       PC  Strategy  Take-Two Interactive        0        0        0
# 7111      PS4  Platform             Team Meat        0        0        0
#
#      Other_Sales Global_Sales Rating Critic_Score_Class
# ...

# %%
df_estadisticas.to_csv('df_estadisticas.csv')
