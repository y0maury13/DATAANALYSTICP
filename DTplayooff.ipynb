# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_play=pd.read_csv('nba_playoffs.csv')

# %%
df_play
# Out:
#             team team_short conference  games_won  games_lose  \
# 0        Nuggets        DEN       West         53          29
# 1          Bucks        MIL       East         58          24
# 2        Celtics        BOS       East         57          25
# 3      Grizzlies        MEM       West         51          31
# 4          76ers        PHI       East         54          28
# 5          Kings        SAC       West         48          34
# 6      Cavaliers        CLE       East         51          31
# 7           Suns        PHX       West         45          37
# 8       Clippers        LAC       West         44          38
# 9         Knicks        NYK       East         47          35
# 10      Warriors        GSW       West         44          38
# 11          Nets        BKN       East         45          37
# 12        Lakers        LAL       West         43          39
# 13          Heat        MIA       East         44          38
# ...

# %%
df_play.info
# Out:
# <bound method DataFrame.info of             team team_short conference  games_won  games_lose  \
# 0        Nuggets        DEN       West         53          29
# 1          Bucks        MIL       East         58          24
# 2        Celtics        BOS       East         57          25
# 3      Grizzlies        MEM       West         51          31
# 4          76ers        PHI       East         54          28
# 5          Kings        SAC       West         48          34
# 6      Cavaliers        CLE       East         51          31
# 7           Suns        PHX       West         45          37
# 8       Clippers        LAC       West         44          38
# 9         Knicks        NYK       East         47          35
# 10      Warriors        GSW       West         44          38
# 11          Nets        BKN       East         45          37
# 12        Lakers        LAL       West         43          39
# 13          Heat        MIA       East         44          38
# ...

# %%
df_play.head()
# Out:
#         team team_short conference  games_won  games_lose conference_position  \
# 0    Nuggets        DEN       West         53          29               34-18
# 1      Bucks        MIL       East         58          24               35-17
# 2    Celtics        BOS       East         57          25               34-18
# 3  Grizzlies        MEM       West         51          31               30-22
# 4      76ers        PHI       East         54          28               34-18
#
#    games_played  points_scored  points_missed  game_won_home  game_lose_home  \
# 0            82          115.8          112.5             34               7
# 1            82          116.9          113.3             32               9
# 2            82          117.9          111.4             32               9
# 3            82          116.9          113.0             35               6
# 4            82          115.2          110.9             29              12
#
# ...

# %%
df_play.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 20 non-null     object
#  1   team_short           20 non-null     object
#  2   conference           20 non-null     object
#  3   games_won            20 non-null     int64
#  4   games_lose           20 non-null     int64
#  5   conference_position  20 non-null     object
#  6   games_played         20 non-null     int64
#  7   points_scored        20 non-null     float64
#  8   points_missed        20 non-null     float64
#  9   game_won_home        20 non-null     int64
#  10  game_lose_home       20 non-null     int64
#  11  game_won_away        20 non-null     int64
#  12  game_lose_away       20 non-null     int64
#  13  seed                 20 non-null     int64
#  14  conf_abbr            20 non-null     object
# ...

# %%
df_play.isnull()
# Out:
#      team  team_short  conference  games_won  games_lose  conference_position  \
# 0   False       False       False      False       False                False
# 1   False       False       False      False       False                False
# 2   False       False       False      False       False                False
# 3   False       False       False      False       False                False
# 4   False       False       False      False       False                False
# 5   False       False       False      False       False                False
# 6   False       False       False      False       False                False
# 7   False       False       False      False       False                False
# 8   False       False       False      False       False                False
# 9   False       False       False      False       False                False
# 10  False       False       False      False       False                False
# ...

# %%
df_play.describe
# Out:
# <bound method NDFrame.describe of             team team_short conference  games_won  games_lose  \
# 0        Nuggets        DEN       West         53          29
# 1          Bucks        MIL       East         58          24
# 2        Celtics        BOS       East         57          25
# 3      Grizzlies        MEM       West         51          31
# 4          76ers        PHI       East         54          28
# 5          Kings        SAC       West         48          34
# 6      Cavaliers        CLE       East         51          31
# 7           Suns        PHX       West         45          37
# 8       Clippers        LAC       West         44          38
# 9         Knicks        NYK       East         47          35
# 10      Warriors        GSW       West         44          38
# 11          Nets        BKN       East         45          37
# 12        Lakers        LAL       West         43          39
# 13          Heat        MIA       East         44          38
# ...

# %%
df_play.describe()
# Out:
#        games_won  games_lose  games_played  points_scored  points_missed  \
# count  20.000000   20.000000          20.0      20.000000      20.000000
# mean   46.500000   35.500000          82.0     115.500000     113.295000
# std     5.642881    5.642881           0.0       2.672472       2.908151
# min    40.000000   24.000000          82.0     109.500000     106.900000
# 25%    42.000000   31.000000          82.0     113.550000     111.550000
# 50%    44.500000   37.500000          82.0     115.800000     112.750000
# 75%    51.000000   40.000000          82.0     117.275000     115.950000
# max    58.000000   42.000000          82.0     120.700000     118.100000
#
#        game_won_home  game_lose_home  game_won_away  game_lose_away       seed
# count      20.000000       20.000000      20.000000       20.000000  20.000000
# mean       27.100000       13.900000      19.400000       21.600000   5.500000
# ...

# %%
print ((df_play["team_short"]))
# Out:
# 0     DEN
# 1     MIL
# 2     BOS
# 3     MEM
# 4     PHI
# 5     SAC
# 6     CLE
# 7     PHX
# 8     LAC
# 9     NYK
# 10    GSW
# 11    BKN
# 12    LAL
# 13    MIA
# 14    ATL
# 15    MIN
# 16    NOP
# 17    TOR
# 18    CHI
# 19    OKC
# Name: team_short, dtype: object

# %%
df_play.games_won
# Out:
# 0     53
# 1     58
# 2     57
# 3     51
# 4     54
# 5     48
# 6     51
# 7     45
# 8     44
# 9     47
# 10    44
# 11    45
# 12    43
# 13    44
# 14    41
# 15    42
# 16    42
# 17    41
# 18    40
# 19    40
# Name: games_won, dtype: int64

# %%
print ((df_play["conference_position"]))
# Out:
# 0     34-18
# 1     35-17
# 2     34-18
# 3     30-22
# 4     34-18
# 5     32-20
# 6     34-18
# 7     30-22
# 8     27-25
# 9     32-20
# 10    30-22
# 11    30-22
# 12    27-25
# 13    24-28
# 14    26-26
# 15    29-23
# 16    29-23
# 17    26-26
# 18    27-25
# 19    25-27
# Name: conference_position, dtype: object

# %%
print ((df_play["games_won"]))
# Out:
# 0     53
# 1     58
# 2     57
# 3     51
# 4     54
# 5     48
# 6     51
# 7     45
# 8     44
# 9     47
# 10    44
# 11    45
# 12    43
# 13    44
# 14    41
# 15    42
# 16    42
# 17    41
# 18    40
# 19    40
# Name: games_won, dtype: int64

# %%
df_play[["games_won","games_played"]]
# Out:
#     games_won  games_played
# 0          53            82
# 1          58            82
# 2          57            82
# 3          51            82
# 4          54            82
# 5          48            82
# 6          51            82
# 7          45            82
# 8          44            82
# 9          47            82
# 10         44            82
# 11         45            82
# 12         43            82
# 13         44            82
# 14         41            82
# 15         42            82
# 16         42            82
# 17         41            82
# 18         40            82
# 19         40            82

# %%
df_play[["team","games_played"]]
# Out:
#             team  games_played
# 0        Nuggets            82
# 1          Bucks            82
# 2        Celtics            82
# 3      Grizzlies            82
# 4          76ers            82
# 5          Kings            82
# 6      Cavaliers            82
# 7           Suns            82
# 8       Clippers            82
# 9         Knicks            82
# 10      Warriors            82
# 11          Nets            82
# 12        Lakers            82
# 13          Heat            82
# 14         Hawks            82
# 15  Timberwolves            82
# 16      Pelicans            82
# 17       Raptors            82
# 18         Bulls            82
# 19       Thunder            82

# %%
df_play[1:5]
# Out:
#         team team_short conference  games_won  games_lose conference_position  \
# 1      Bucks        MIL       East         58          24               35-17
# 2    Celtics        BOS       East         57          25               34-18
# 3  Grizzlies        MEM       West         51          31               30-22
# 4      76ers        PHI       East         54          28               34-18
#
#    games_played  points_scored  points_missed  game_won_home  game_lose_home  \
# 1            82          116.9          113.3             32               9
# 2            82          117.9          111.4             32               9
# 3            82          116.9          113.0             35               6
# 4            82          115.2          110.9             29              12
#
#    game_won_away  game_lose_away  seed conf_abbr
# 1             26              15     1         E
# 2             25              16     2         E
# ...

# %%
df_play[3:20]
# Out:
#             team team_short conference  games_won  games_lose  \
# 3      Grizzlies        MEM       West         51          31
# 4          76ers        PHI       East         54          28
# 5          Kings        SAC       West         48          34
# 6      Cavaliers        CLE       East         51          31
# 7           Suns        PHX       West         45          37
# 8       Clippers        LAC       West         44          38
# 9         Knicks        NYK       East         47          35
# 10      Warriors        GSW       West         44          38
# 11          Nets        BKN       East         45          37
# 12        Lakers        LAL       West         43          39
# 13          Heat        MIA       East         44          38
# 14         Hawks        ATL       East         41          41
# 15  Timberwolves        MIN       West         42          40
# 16      Pelicans        NOP       West         42          40
# ...
