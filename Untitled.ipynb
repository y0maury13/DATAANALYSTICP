# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("df_estadisticas.csv")

# %%
df
# Out:
#       Unnamed: 0 Platform     Genre             Publisher NA_Sales EU_Sales  \
# 0              0      Wii    Sports              Nintendo    41,36    28,96
# 1              1      Wii    Racing              Nintendo    15,68     12,8
# 2              2      Wii    Sports              Nintendo    15,61    10,95
# 3              3       DS  Platform              Nintendo    11,28     9,15
# 4              4      Wii      Misc              Nintendo    13,96     9,18
# ...          ...      ...       ...                   ...      ...      ...
# 7107        7107       PC    Action               Ubisoft        0        0
# 7108        7108       PC   Shooter          Midway Games        0        0
# 7109        7109       PC    Sports                  Sega        0        0
# 7110        7110       PC  Strategy  Take-Two Interactive        0        0
# 7111        7111      PS4  Platform             Team Meat        0        0
#
# ...
